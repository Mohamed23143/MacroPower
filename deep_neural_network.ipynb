# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed23143/MacroPower/blob/master/deep_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Install unrar (Colab doesn't have it by default)
# !apt-get install unrar

# 3. Extract the .rar file to a folder
# !unrar x "/content/drive/MyDrive/Nlp course/Airline_Delay_Cause.rar" "/content/Airline_Delay_Cause/"

# 4. Check extracted files
# !ls "/content/Airline_Delay_Cause/"

# 5. Example: read a CSV from the extracted folder
import pandas as pd
data = pd.read_csv("/content/Airline_Delay_Cause/Airline_Delay_Cause.csv")
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Nlp course/Airline_Delay_Cause.rar
#
# Creating    /content/Airline_Delay_Cause                              OK
#   OK
# All OK
# Airline_Delay_Cause.csv
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317527 non-null  float64
#  15  arr_delay            317523 non-null  float64
#  16  carrier_delay        317525 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317527 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
data=data.drop(['carrier','carrier_name','airport','airport_name'],axis=1)

# %%
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [318017 rows x 17 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317268 entries, 0 to 318016
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317268 non-null  int64
#  1   month                317268 non-null  int64
#  2   arr_flights          317268 non-null  float64
#  3   arr_del15            317268 non-null  float64
#  4   carrier_ct           317268 non-null  float64
#  5   weather_ct           317268 non-null  float64
#  6   nas_ct               317268 non-null  float64
#  7   security_ct          317268 non-null  float64
#  8   late_aircraft_ct     317268 non-null  float64
#  9   arr_cancelled        317268 non-null  float64
#  10  arr_diverted         317268 non-null  float64
#  11  arr_delay            317268 non-null  float64
#  12  carrier_delay        317268 non-null  float64
#  13  weather_delay        317268 non-null  float64
#  14  nas_delay            317268 non-null  float64
#  15  security_delay       317268 non-null  float64
#  16  late_aircraft_delay  317268 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 43.6 MB

# %%
data['weather_delay'].min(),data['weather_delay'].max()
# Out:
# (0.0, 57707.0)

# %%
data['WDCase']=data['weather_delay'].apply(lambda x: 1 if x >100 else 0)

# %%
data['WDCase'].value_counts()
# Out:
# WDCase
# 0    215116
# 1    102152
# Name: count, dtype: int64

# %%
X=data.drop(['WDCase'],axis=1)
X
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [317268 rows x 17 columns]

# %%
y=data['WDCase']
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 318012    1
# 318013    1
# 318014    0
# 318015    0
# 318016    1
# Name: WDCase, Length: 317268, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44, shuffle =True)

print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (237951, 17)
# X_test shape is  (79317, 17)
# y_train shape is  (237951,)
# y_test shape is  (79317,)

# %%
import tensorflow as tf
import keras

# %%
from tensorflow.keras.optimizers import AdamW

# %%
KerasModel=keras.models.Sequential([
    #keras.layers.input(shape=(17))
    keras.layers.Dense(8,activation="tanh"),
    #keras.layers.Dropout(0,1)
    keras.layers.Dense(128,activation="sigmoid"),
    #keras.layers.Dropout(0,3)
    keras.layers.Dense(64,activation="tanh"),
    keras.layers.Dense(32,activation="tanh"),
    keras.layers.Dropout(0,2),
   keras.layers.Dense(1,activation="sigmoid")

])

# %%
MyOptimizer = tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    name="AdamW")

# %%
KerasModel.compile(optimizer=MyOptimizer,loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = KerasModel.fit(X_train,y_train,
                         validation_data=(X_test,y_test),
                         epochs=100,
                         batch_size=10000,
                         verbose=1,
                         callbacks=[tf.keras.callbacks.EarlyStopping(
                                            patience=10,
                                            monitor='val_accuracy',#"val_loss",
                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6972 - loss: 0.5961 - val_accuracy: 0.7776 - val_loss: 0.5056
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7745 - loss: 0.4985 - val_accuracy: 0.7879 - val_loss: 0.4816
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7789 - loss: 0.4788 - val_accuracy: 0.7843 - val_loss: 0.4675
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7845 - loss: 0.4632 - val_accuracy: 0.7792 - val_loss: 0.4575
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7762 - loss: 0.4554 - val_accuracy: 0.7763 - val_loss: 0.4506
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7812 - loss: 0.4487 - val_accuracy: 0.7929 - val_loss: 0.4452
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7974 - loss: 0.4404 - val_accuracy: 0.7978 - val_loss: 0.4367
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8011 - loss: 0.4325 - val_accuracy: 0.8074 - val_loss: 0.4295
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8099 - loss: 0.4265 - val_accuracy: 0.8129 - val_loss: 0.4207
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8139 - loss: 0.4162 - val_accuracy: 0.8173 - val_loss: 0.4098
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8180 - loss: 0.4049 - val_accuracy: 0.8169 - val_loss: 0.3995
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.
100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9951 - loss: 0.0227 - val_accuracy: 0.9981 - val_loss: 0.0090
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9979 - loss: 0.0096 - val_accuracy: 0.9957 - val_loss: 0.0217
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9974 - loss: 0.0122 - val_accuracy: 0.9988 - val_loss: 0.0054
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.9987 - val_loss: 0.0055
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9982 - loss: 0.0088 - val_accuracy: 0.9974 - val_loss: 0.0118
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9980 - loss: 0.0090 - val_accuracy: 0.9990 - val_loss: 0.0048
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9976 - val_loss: 0.0116
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9979 - loss: 0.0089 - val_accuracy: 0.9979 - val_loss: 0.0099
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0162 - val_accuracy: 0.9987 - val_loss: 0.0061
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9987 - loss: 0.0057 - val_accuracy: 0.9988 - val_loss: 0.0051
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9977 - loss: 0.0108 - val_accuracy: 0.9980 - val_loss: 0.0080
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9986 - loss: 0.0061 - val_accuracy: 0.9967 - val_loss: 0.0148
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9981 - loss: 0.0082 - val_accuracy: 0.9978 - val_loss: 0.0104
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9970 - loss: 0.0140 - val_accuracy: 0.9969 - val_loss: 0.0168
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9971 - loss: 0.0143 - val_accuracy: 0.9963 - val_loss: 0.0206
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9962 - loss: 0.0186 - val_accuracy: 0.9984 - val_loss: 0.0077

# %%
print(KerasModel.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,997 (136.71 KB)
#  Trainable params: 11,665 (45.57 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 23,332 (91.14 KB)
# None

# %%
KerasModel.save('KerasModel.keras')

# %%
NewKerasModel = keras.models.load_model('KerasModel.keras')

# %%
X_test
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 256596  2007      1        213.0       64.0       16.33        3.44   15.06
# 6930    2022      1        617.0       82.0       29.69        2.04   26.88
# 125951  2014     11         62.0        8.0        3.00        0.00    2.09
# 87817   2017     10         82.0        9.0        6.00        1.20    1.00
# 42037   2020      3        168.0       12.0        6.65        2.00    1.04
# ...      ...    ...          ...        ...         ...         ...     ...
# 132929  2014      5       2410.0      637.0      222.01        9.35   56.16
# 251541  2007      4         42.0        8.0        5.83        0.00    1.50
# 84057   2018      1         80.0       12.0        3.48        3.92    0.12
# 32889   2020     10        356.0       23.0        8.12        0.00   10.33
# 269836  2006      4       1075.0      181.0       56.35        1.40   82.43
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 256596         0.00             29.17           13.0           0.0     3840.0
# 6930           0.30             23.08           27.0           1.0     5410.0
# 125951         0.00              2.91            0.0           0.0      609.0
# 87817          0.00              0.80            0.0           0.0      260.0
# 42037          0.00              2.31           19.0           0.0      558.0
# ...             ...               ...            ...           ...        ...
# 132929         0.85            348.62           13.0           0.0    34346.0
# 251541         0.00              0.67            1.0           0.0      306.0
# 84057          0.00              4.48            2.0           0.0     1060.0
# 32889          0.00              4.56            0.0           2.0      989.0
# 269836         0.77             40.05            4.0           2.0     7544.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 256596          912.0          292.0      720.0             0.0
# 6930           2471.0          157.0     1095.0            15.0
# 125951          391.0            0.0      123.0             0.0
# 87817           201.0           22.0       17.0             0.0
# 42037           331.0           73.0       43.0             0.0
# ...               ...            ...        ...             ...
# 132929         9518.0          842.0     2427.0            38.0
# 251541          234.0            0.0       58.0             0.0
# 84057            97.0          721.0       13.0             0.0
# 32889           516.0            0.0      260.0             0.0
# 269836         2914.0           78.0     2205.0            75.0
#
#         late_aircraft_delay
# 256596               1916.0
# 6930                 1672.0
# 125951                 95.0
# 87817                  20.0
# 42037                 111.0
# ...                     ...
# 132929              21521.0
# 251541                 14.0
# 84057                 229.0
# 32889                 213.0
# 269836               2272.0
#
# [79317 rows x 17 columns]

# %%
y_pred = NewKerasModel.predict(X_test)
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 2s 763us/step

# %%
print('Prediction items are {}'.format(y_pred[:5]))
# Out:
# Prediction items are [[9.9862504e-01]
#  [9.9862504e-01]
#  [1.4970388e-04]
#  [1.4970388e-04]
#  [1.4970388e-04]]

# %%
y_test[:5]
# Out:
# 256596    1
# 6930      1
# 125951    0
# 87817     0
# 42037     0
# Name: WDCase, dtype: int64

# %%
ModelLoss, ModelAccuracy = NewKerasModel.evaluate(X_test, y_test)
print('Model Loss is {}'.format(ModelLoss))
print('Model Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 3s 989us/step - accuracy: 0.9990 - loss: 0.0047
# Model Loss is 0.004789123777300119
# Model Accuracy is 0.9989787936210632

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
len(y_test), len(y_pred)
# Out:
# (79317, 79317)

# %%
y_pred
# Out:
# array([[9.9862504e-01],
#        [9.9862504e-01],
#        [1.4970388e-04],
#        ...,
#        [9.9934274e-01],
#        [1.4948334e-04],
#        [3.9551840e-03]], dtype=float32)

# %%
y_pred = [np.round(i[0]) for i in y_pred]
y_pred
# Out:
# [np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  ...]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
CM = confusion_matrix(y_test, y_pred)
print('Confusion Matrix is : \n', CM)
# Out:
# Confusion Matrix is :
#  [[53662    62]
#  [   19 25574]]

# %%
# drawing confusion matrix
sns.heatmap(CM, center = True,cmap='Blues_r')
plt.show()

# %%
from sklearn.metrics import classification_report
ClassificationReport = classification_report(y_test,y_pred)
print('Classification Report is : \n', ClassificationReport )
# Out:
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     53724
#            1       1.00      1.00      1.00     25593
#
#     accuracy                           1.00     79317
#    macro avg       1.00      1.00      1.00     79317
# weighted avg       1.00      1.00      1.00     79317
